# %% [markdown]
# ## 13. Model Testing with New Inputs

# %%
import pickle

with open("best_model.pkl", "rb") as file:
    loaded_model = pickle.load(file)

# %%
sample_input = X_test.iloc[[0]]
sample_input
# Out:
#        lead_time  arrival_date_year  arrival_date_week_number  \
# 12449         51               2017                        26
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 12449                         30                        2
#
#        stays_in_week_nights  adults  children  babies  is_repeated_guest  ...  \
# 12449                     2       2       0.0       0                  0  ...
#
#        assigned_room_type_H  assigned_room_type_I  assigned_room_type_K  \
# 12449                 False                 False                 False
#
#        assigned_room_type_L  assigned_room_type_P  deposit_type_Non Refund  \
# 12449                 False                 False                    False
#
#        deposit_type_Refundable  customer_type_Group  customer_type_Transient  \
# 12449                    False                False                     True
#
#        customer_type_Transient-Party
# 12449                          False
#
# [1 rows x 246 columns]

# %%
prediction = loaded_model.predict(sample_input)
probability = loaded_model.predict_proba(sample_input)

print("Prediction:", prediction[0])
print("Probability:", probability)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_310/495963336.py in <cell line: 0>()
# ----> 1 prediction = loaded_model.predict(sample_input)
#       2 probability = loaded_model.predict_proba(sample_input)
#       3
#       4 print("Prediction:", prediction[0])
#       5 print("Probability:", probability)
#
# NameError: name 'loaded_model' is not defined

# %%
if prediction[0] == 1:
    print("The booking is predicted to be Canceled.")
else:
    print("The booking is predicted to be Not Canceled.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_310/74948587.py in <cell line: 0>()
# ----> 1 if prediction[0] == 1:
#       2     print("The booking is predicted to be Canceled.")
#       3 else:
#       4     print("The booking is predicted to be Not Canceled.")
#
# NameError: name 'prediction' is not defined
